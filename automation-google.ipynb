# %%
import requests
import gdown

save_location = "Testing/g-down-download.csv"

gdown.download(url, save_location)

with open(save_location) as file:
    for line in file:
        print(line)
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1idotGHUrpHVjBzb6C_LjFCJp9BxWJySXtbFVvMCmPpM/gviz/tq?tqx=out:csv
# To: /Users/ajpietrick/Documents/Coding/SplashtagChecker/Testing/g-down-download.csv
# 10.8kB [00:00, 3.85MB/s]
# "Team Name","Team's University","Secondary Contact","Player 1's Splashtag","Player 1's Discord Username","Player 2's Splashtag","Player 2's Discord Username","Player 3's Splashtag","Player 3's Discord Username","Player 4's Splashtag","Player 4's Discord Username","Player 5's Splashtag","Player 5's Discord Username","Player 6's Splashtag","Player 6's Discord Username","Player 7's Splashtag","Player 7's Discord Username","Player 8's Splashtag","Player 8's Discord Username"
#
# "Rising Moon","Purdue University, Fort Wayne","","ΩMinty#1652","craftymint6","ΩSquishy✖#3348","abyssal.limbo","ΩSlumpSkul#1963","slumpskull_","ΩFily#5524","djfilly","ΩKowitos#1994","kowitos","","","","","",""
#
# ...
